# %% [markdown]
# # Single URL

# %%
import requests
import re
import json

import warnings
warnings.filterwarnings('ignore')

url='https://www.zillow.com/homes/for_sale/2_p/?searchQueryState=%7B%22pagination%22%3A%7B%22currentPage%22%3A2%7D%2C%22mapBounds%22%3A%7B%22west%22%3A-97.88981437683105%2C%22east%22%3A-97.78407096862793%2C%22south%22%3A30.136145838104586%2C%22north%22%3A30.208863801102932%7D%2C%22isMapVisible%22%3Atrue%2C%22filterState%22%3A%7B%22sort%22%3A%7B%22value%22%3A%22days%22%7D%2C%22ah%22%3A%7B%22value%22%3Atrue%7D%7D%2C%22isListVisible%22%3Atrue%2C%22mapZoom%22%3A13%7D'

data = json.loads(re.search(r'!--(\{"queryState".*?)-->', r.text).group(1))

df = pd.DataFrame()

for item in data['cat1']['searchResults']['listResults']:
    df = df.append(item, ignore_index=True)

#drop cols
df = df.drop('hdpData', 1) #remove this line to see a whole bunch of other random cols, in dict format

print('shape:', df.shape)
display(df.head())
# Out:
# shape: (40, 48)
#         zpid         id providerListingId                                                                       imgSrc  hasImage                                                                               detailUrl statusType statusText countryCurrency     price  unformattedPrice                                 address         addressStreet addressCity addressState addressZipcode  isUndisclosedAddress  beds  baths  area                                           latLong  isZillowOwned                                     variableData badgeInfo  isSaved  isUserClaimingOwner  isUserConfirmedClaim    pgapt              sgapt zestimate  shouldShowZestimateAsPrice  has3DModel  hasVideo  isHomeRec               info2String                                                                               info3String              brokerName  hasAdditionalAttributions  isFeaturedListing availabilityDate  list  relaxed lotAreaString builderName hasOpenHouse openHouseDescription openHouseEndDate  \
# 0   29497722   29497722              None  https://photos.zillowstatic.com/fp/df3476e682ef82e445effb781e59ec8e-p_e.jpg      True          https://www.zillow.com/homedetails/2015-Lear-Ln-Austin-TX-78745/29497722_zpid/   FOR_SALE     Active               $  $600,000            600000          2015 Lear Ln, Austin, TX 78745          2015 Lear Ln      Austin           TX          78745                 False     4    3.0  2250  {'latitude': 30.196585, 'longitude': -97.811516}          False           {'type': '3D_HOME', 'text': '3D Tour'}      None    False                False                 False  ForSale  For Sale (Broker)      None                       False        True     False      False  Listing provided by ABOR  https://photos.zillowstatic.com/fp/98ab7c7b2895c2f5f278917766712625-zillow_web_48_23.jpg         eXp Realty, LLC                       True              False             None  True    False           NaN         NaN          NaN                  NaN              NaN
# 1   29512726   29512726              None  https://photos.zillowstatic.com/fp/7d1a7ff26d5789e55eaafd3547835be8-p_e.jpg      True       https://www.zillow.com/homedetails/4102-Tecate-Trl-Austin-TX-78739/29512726_zpid/   FOR_SALE     Active               $  $625,000            625000       4102 Tecate Trl, Austin, TX 78739       4102 Tecate Trl      Austin           TX          78739                 False     3    2.0  1746   {'latitude': 30.169558, 'longitude': -97.86904}          False  {'type': 'DAYS_ON', 'text': '4 days on Zillow'}      None    False                False                 False  ForSale  For Sale (Broker)      None                       False       False     False      False  Listing provided by ABOR  https://photos.zillowstatic.com/fp/98ab7c7b2895c2f5f278917766712625-zillow_web_48_23.jpg  Keller Williams Realty                       True              False             None  True    False           NaN         NaN          NaN                  NaN              NaN
# 2  119617777  119617777              None  https://photos.zillowstatic.com/fp/81dede3b674ccb042769f132b4fc7763-p_e.jpg      True  https://www.zillow.com/homedetails/7337-Menchaca-Rd-36-Austin-TX-78745/119617777_zpid/   FOR_SALE     Active               $  $470,000            470000  7337 Menchaca Rd #36, Austin, TX 78745  7337 Menchaca Rd #36      Austin           TX          78745                 False     3    2.0  1501     {'latitude': 30.1987, 'longitude': -97.80799}          False  {'type': 'DAYS_ON', 'text': '4 days on Zillow'}      None    False                False                 False  ForSale  For Sale (Broker)    588300                       False       False     False      False  Listing provided by ABOR  https://photos.zillowstatic.com/fp/98ab7c7b2895c2f5f278917766712625-zillow_web_48_23.jpg           Realty Austin                       True              False             None  True    False           NaN         NaN          NaN                  NaN              NaN
# 3   29488852   29488852              None  https://photos.zillowstatic.com/fp/c14a2b360970127d69af979165e29e63-p_e.jpg      True      https://www.zillow.com/homedetails/3214-Barnsley-Dr-Austin-TX-78745/29488852_zpid/   FOR_SALE     Active               $  $539,500            539500      3214 Barnsley Dr, Austin, TX 78745      3214 Barnsley Dr      Austin           TX          78745                 False     3    2.0  1190   {'latitude': 30.205084, 'longitude': -97.82862}          False  {'type': 'DAYS_ON', 'text': '4 days on Zillow'}      None    False                False                 False  ForSale  For Sale (Broker)      None                       False       False     False      False  Listing provided by ABOR  https://photos.zillowstatic.com/fp/98ab7c7b2895c2f5f278917766712625-zillow_web_48_23.jpg  Keller Williams Realty                       True              False             None  True    False           NaN         NaN          NaN                  NaN              NaN
# 4  119624978  119624978              None  https://photos.zillowstatic.com/fp/2a865d8b9e2450744744c598ce914405-p_e.jpg      True     https://www.zillow.com/homedetails/10041-Aly-May-Dr-Austin-TX-78748/119624978_zpid/   FOR_SALE     Active               $  $530,000            530000      10041 Aly May Dr, Austin, TX 78748      10041 Aly May Dr      Austin           TX          78748                 False     3    3.0  2180  {'latitude': 30.169004, 'longitude': -97.817986}          False  {'type': 'DAYS_ON', 'text': '4 days on Zillow'}      None    False                False                 False  ForSale  For Sale (Broker)      None                       False       False     False      False  Listing provided by ABOR  https://photos.zillowstatic.com/fp/98ab7c7b2895c2f5f278917766712625-zillow_web_48_23.jpg           Realty Austin                       True              False             None  True    False           NaN         NaN          NaN                  NaN              NaN
#
#   openHouseStartDate
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %% [markdown]
# # Multiple URLs

# %%
import requests
import re
import json
import time

import warnings
warnings.filterwarnings('ignore')

city = 'austin/' #*****change this city to what you want!!!!*****

#just grabbing the first 20 pages
#feel free to make this prettier
url1 = 'https://www.zillow.com/homes/for_sale/'+city
url2 = 'https://www.zillow.com/homes/for_sale/'+city+'/2_p/'
url3 = 'https://www.zillow.com/homes/for_sale/'+city+'/3_p/'
url4 = 'https://www.zillow.com/homes/for_sale/'+city+'/4_p/'
url5 = 'https://www.zillow.com/homes/for_sale/'+city+'/5_p/'
url6 = 'https://www.zillow.com/homes/for_sale/'+city+'/6_p/'
url7 = 'https://www.zillow.com/homes/for_sale/'+city+'/7_p/'
url8 = 'https://www.zillow.com/homes/for_sale/'+city+'/8_p/'
url9 = 'https://www.zillow.com/homes/for_sale/'+city+'/9_p/'
url10 = 'https://www.zillow.com/homes/for_sale/'+city+'/10_p/'
# url11 = 'https://www.zillow.com/homes/for_sale/'+city+'/11_p/'
# url12 = 'https://www.zillow.com/homes/for_sale/'+city+'/12_p/'
# url13 = 'https://www.zillow.com/homes/for_sale/'+city+'/13_p/'
# url14 = 'https://www.zillow.com/homes/for_sale/'+city+'/14_p/'
# url15 = 'https://www.zillow.com/homes/for_sale/'+city+'/15_p/'
# url16 = 'https://www.zillow.com/homes/for_sale/'+city+'/16_p/'
# url17 = 'https://www.zillow.com/homes/for_sale/'+city+'/17_p/'
# url18 = 'https://www.zillow.com/homes/for_sale/'+city+'/18_p/'
# url19 = 'https://www.zillow.com/homes/for_sale/'+city+'/19_p/'
# url20 = 'https://www.zillow.com/homes/for_sale/'+city+'/20_p/'

r1 = requests.get(url1,headers = {'User-Agent':'Mozilla/5.0'})
r2 = requests.get(url2,headers = {'User-Agent':'Mozilla/5.0'})
r3 = requests.get(url3,headers = {'User-Agent':'Mozilla/5.0'})
r4 = requests.get(url4,headers = {'User-Agent':'Mozilla/5.0'})
r5 = requests.get(url5,headers = {'User-Agent':'Mozilla/5.0'})
r6 = requests.get(url6,headers = {'User-Agent':'Mozilla/5.0'})
r7 = requests.get(url7,headers = {'User-Agent':'Mozilla/5.0'})
r8 = requests.get(url8,headers = {'User-Agent':'Mozilla/5.0'})
r9 = requests.get(url9,headers = {'User-Agent':'Mozilla/5.0'})
r10 = requests.get(url10,headers = {'User-Agent':'Mozilla/5.0'})
# r11 = requests.get(url11,headers = {'User-Agent':'Mozilla/5.0'})
# r12 = requests.get(url12,headers = {'User-Agent':'Mozilla/5.0'})
# r13 = requests.get(url13,headers = {'User-Agent':'Mozilla/5.0'})
# r14 = requests.get(url14,headers = {'User-Agent':'Mozilla/5.0'})
# r15 = requests.get(url15,headers = {'User-Agent':'Mozilla/5.0'})
# r16 = requests.get(url16,headers = {'User-Agent':'Mozilla/5.0'})
# r17 = requests.get(url17,headers = {'User-Agent':'Mozilla/5.0'})
# r18 = requests.get(url18,headers = {'User-Agent':'Mozilla/5.0'})
# r19 = requests.get(url19,headers = {'User-Agent':'Mozilla/5.0'})
# r20 = requests.get(url20,headers = {'User-Agent':'Mozilla/5.0'})

time.sleep(3)
data1 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r1.text).group(1))
time.sleep(3)
data2 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r2.text).group(1))
time.sleep(3)
data3 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r3.text).group(1))
time.sleep(3)
data4 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r4.text).group(1))
time.sleep(3)
data5 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r5.text).group(1))
time.sleep(3)
data6 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r6.text).group(1))
time.sleep(3)
data7 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r7.text).group(1))
time.sleep(3)
data8 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r8.text).group(1))
time.sleep(3)
data9 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r9.text).group(1))
time.sleep(3)
data10 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r10.text).group(1))
# data11 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r11.text).group(1))
# data12 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r12.text).group(1))
# data13 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r13.text).group(1))
# data14 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r14.text).group(1))
# data15 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r15.text).group(1))
# data16 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r16.text).group(1))
# data17 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r17.text).group(1))
# data18 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r18.text).group(1))
# data19 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r19.text).group(1))
# data20 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r20.text).group(1))

data_list = [data1,data2,data3,data4,data5,data6,data7,data8,data9,data10]
            # ,data11,data12,data13,data14,data15,data16,data17,data18,data19,data20]

df = pd.DataFrame()

def make_frame(frame):
    for i in data_list:
        for item in i['cat1']['searchResults']['listResults']:
            frame = frame.append(item, ignore_index=True)
    return frame

df = make_frame(df)
    
#drop cols
df = df.drop('hdpData', 1) #remove this line to see a whole bunch of other random cols, in dict format

print('shape:', df.shape)
display(df.head())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-131-f18b72b94245> in <module>
#      54
#      55 time.sleep(3)
# ---> 56 data1 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r1.text).group(1))
#      57 time.sleep(3)
#      58 data2 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r2.text).group(1))
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
df
# Out:
#            zpid          id providerListingId                                                                       imgSrc  hasImage                                                                                              detailUrl statusType        statusText countryCurrency        price  unformattedPrice                                               address                                       addressStreet   addressCity addressState addressZipcode  isUndisclosedAddress  beds  baths   area                                           latLong  isZillowOwned                                                                  variableData badgeInfo  isSaved  isUserClaimingOwner  isUserConfirmedClaim    pgapt              sgapt zestimate  shouldShowZestimateAsPrice  has3DModel  hasVideo  isHomeRec               info2String                                                                               info3String                             brokerName  hasAdditionalAttributions  \
# 0      58313342    58313342              None  https://photos.zillowstatic.com/fp/e80b7277efb2bbf763c1d123e09339a2-p_e.jpg      True                    https://www.zillow.com/homedetails/4609-Arapahoe-Trl-Austin-TX-78745/58313342_zpid/   FOR_SALE            Active               $     $500,000            500000                   4609 Arapahoe Trl, Austin, TX 78745                                   4609 Arapahoe Trl        Austin           TX          78745                 False     3    2.0   1590   {'latitude': 30.226486, 'longitude': -97.79708}          False                               {'type': 'DAYS_ON', 'text': '4 days on Zillow'}      None    False                False                 False  ForSale  For Sale (Broker)      None                       False       False     False      False  Listing provided by ABOR  https://photos.zillowstatic.com/fp/98ab7c7b2895c2f5f278917766712625-zillow_web_48_23.jpg                             Sky Realty                       True
# 1    2128879380  2128879380              None  https://photos.zillowstatic.com/fp/36395d1ea2984447a0677245fc6ef051-p_e.jpg      True                   https://www.zillow.com/homedetails/11719-Bell-Ave-A-Austin-TX-78759/2128879380_zpid/   FOR_SALE            Active               $     $599,900            599900                   11719 Bell Ave #A, Austin, TX 78759                                   11719 Bell Ave #A        Austin           TX          78759                 False     3    3.0   1832    {'latitude': 30.41951, 'longitude': -97.75088}          False                              {'type': 'DAYS_ON', 'text': '11 days on Zillow'}      None    False                False                 False  ForSale  For Sale (Broker)    627200                       False       False     False      False  Listing provided by ABOR  https://photos.zillowstatic.com/fp/98ab7c7b2895c2f5f278917766712625-zillow_web_48_23.jpg                
False  Listing provided by ABOR  https://photos.zillowstatic.com/fp/98ab7c7b2895c2f5f278917766712625-zillow_web_48_23.jpg           Berkshire Hathaway TX Realty                       True
# 8      29464882    29464882              None  https://photos.zillowstatic.com/fp/c2a3739cbd1201757b0d6b843bf5670d-p_e.jpg      True                       https://www.zillow.com/homedetails/1406-Brandt-Dr-Austin-TX-78742/29464882_zpid/   FOR_SALE            Active               $     $350,000            350000                      1406 Brandt Dr, Austin, TX 78742                                      1406 Brandt Dr        Austin           TX          78742                 False     3    2.0   1514   {'latitude': 30.223072, 'longitude': -97.67374}          False                               {'type': 'DAYS_ON', 'text': '5 days on Zillow'}      None    False                False                 False  ForSale  For Sale (Broker)    291500                       False       False     False      False  Listing provided by ABOR  https://photos.zillowstatic.com/fp/98ab7c7b2895c2f5f278917766712625-zillow_web_48_23.jpg              Richard Michalski, Broker                       True
# 9      70338514    70338514              None  https://photos.zillowstatic.com/fp/2bfb003609cbbc6f246bcb2031a25ae0-p_e.jpg      True                https://www.zillow.com/homedetails/4704-Fort-Moultrie-Ln-Austin-TX-78754/70338514_zpid/   FOR_SALE            Active               $     $400,000            400000               4704 Fort Moultrie Ln, Austin, TX 78754                               4704 Fort Moultrie Ln        Austin           TX          78754                 False     3    2.0   1613   {'latitude': 30.337437, 'longitude': -97.64806}          False                               {'type': 'DAYS_ON', 'text': '3 days on Zillow'}      None    False                False                 False  ForSale  For Sale (Broker)      None                       False       False     False      False  Listing provided by ABOR  https://photos.zillowstatic.com/fp/98ab7c7b2895c2f5f278917766712625-zillow_web_48_23.jpg                          Outlaw Realty                       True
# 10     29381875    29381875              None  https://photos.zillowstatic.com/fp/d55bffb5a98732255d571f39cc7a3a2c-p_e.jpg      True                                      https://www.zillow.com/homedetails/Austin-TX-78704/29381875_zpid/   FOR_SALE            Active               $     $265,000            265000               (undisclosed Address), Austin, TX 78704                               (undisclosed Address)        Austin           TX          78704                  True     0    1.0    397                                                {}          False  {'type': 'TIME_ON_INFO', 'text': '11 hours ago', 'data': {'isFresh': False}}      None    False                False                 False  ForSale  For Sale (Broker)      None                       False       False     False      False  Listing provided by ABOR  https://photos.zillowstatic.com/fp/98ab7c7b2895c2f5f278917766712625-zillow_web_48_23.jpg                     Topper Real Estate                       True
# 11    331629638   331629638              None  https://photos.zillowstatic.com/fp/9a9d44f0c41f9e630daa5e91ef96811a-p_e.jpg      True                  https://www.zillow.com/homedetails/7907-Mellencamp-Dr-Austin-TX-78744/331629638_zpid/   FOR_SALE            Active               $     $415,000            415000                  7907 Mellencamp Dr, Austin, TX 78744                                  7907 Mellencamp Dr        Austin           TX          78744                 False     3    3.0   1583   {'latitude': 30.154762, 'longitude': -97.71586}          False                               {'type': 'DAYS_ON', 'text': '4 days on Zillow'}      None    False                False                 False  ForSale  For Sale (Broker)      None                       False       False     False      False  Listing provided by ABOR  https://photos.zillowstatic.com/fp/98ab7c7b2895c2f5f278917766712625-zillow_web_48_23.jpg                          Realty Austin                       True
# 12     29468622    29468622              None  https://photos.zillowstatic.com/fp/aebdea691c00ad28160eae9d5da3b440-p_e.jpg      True                 https://www.zillow.com/homedetails/5474-Walnut-Grove-Dr-Austin-TX-78744/29468622_zpid/   FOR_SALE            Active               $     $425,000            425000                5474 Walnut Grove Dr, Austin, TX 78744                                5474 Walnut Grove Dr        Austin           TX          78744                 False     3    2.0   1283   {'latitude': 30.189228, 'longitude': -97.73665}          False   {'type': 'TIME_ON_INFO', 'text': '2 hours ago', 'data': {'isFresh': False}}      None    False                False                 False  ForSale  For Sale (Broker)    434100                       False       False     False      False  Listing provided by ABOR  https://photos.zillowstatic.com/fp/98ab7c7b2895c2f5f278917766712625-zillow_web_48_23.jpg                      Orchard Brokerage                       True
# 13     29372632    29372632              None  https://photos.zillowstatic.com/fp/931ba90e0a8a5ac872d9b44af51e7bdc-p_e.jpg      True                 https://www.zillow.com/homedetails/10611-Spicewood-Pkwy-Austin-TX-78750/29372632_zpid/   FOR_SALE            Active               $     $875,000            875000                10611 Spicewood Pkwy, Austin, TX 78750                                10611 Spicewood Pkwy        Austin           TX          78750                 False     3    3.0   2398   {'latitude': 30.430698, 'longitude': -97.80425}          False   {'type': 'TIME_ON_INFO', 'text': '8 hours ago', 'data': {'isFresh': False}}      None    False                False                 False  ForSale  For Sale (Broker)      None                       False       False     False      False  Listing provided by ABOR  https://photos.zillowstatic.com/fp/98ab7c7b2895c2f5f278917766712625-zillow_web_48_23.jpg                    Millikin Properties                       True
# 14     29427277    29427277              None  https://photos.zillowstatic.com/fp/d5d5b5eeee153b3b2ac0893d735d5453-p_e.jpg      True                     https://www.zillow.com/homedetails/8520-Hathaway-Dr-Austin-TX-78757/29427277_zpid/   FOR_SALE            Active               $     $498,077            498077                    8520 Hathaway Dr, Austin, TX 78757                                    8520 Hathaway Dr        Austin           TX          78757                 False     3    2.0   1008  {'latitude': 30.366041, 'longitude': -97.726326}          False  {'type': 'TIME_ON_INFO', 'text': '10 hours ago', 'data': {'isFresh': False}}      None    False                False                 False  ForSale  For Sale (Broker)      None                       False       False     False      False  Listing provided by ABOR  https://photos.zillowstatic.com/fp/98ab7c7b2895c2f5f278917766712625-zillow_web_48_23.jpg                             TOWERS.net                       True
# 15     29359905    29359905              None  https://photos.zillowstatic.com/fp/d1b3a3ab1c699093378156d155177e8f-p_e.jpg      True                      https://www.zillow.com/homedetails/3304-Oxsheer-Dr-Austin-TX-78732/29359905_zpid/   FOR_SALE    House for sale               $   $1,059,000           1059000                     3304 Oxsheer Dr, Austin, TX 78732                                     3304 Oxsheer Dr        Austin           TX          78732                 False     4    3.0   3333   {'latitude': 30.375378, 'longitude': -97.89735}          False                               {'type': 'DAYS_ON', 'text': '7 days on Zillow'}      None    False                False                 False  ForSale  For Sale (Broker)    917800                       False       False     False      False                       NaN                                                                                       NaN  COLDWELL BANKER HOME PLACE - CARTHAGE                       True
# 16     29353867    29353867              None  https://photos.zillowstatic.com/fp/68e88292da1b5571fce8b58553991027-p_e.jpg      True                        https://www.zillow.com/homedetails/6802-Puma-Trl-Austin-TX-78731/29353867_zpid/   FOR_SALE            Active               $     $850,000            850000                       6802 Puma Trl, Austin, TX 78731                                       6802 Puma Trl        Austin           TX          78731                 False     2    3.0   1991   {'latitude': 30.363096, 'longitude': -97.77882}          False                               {'type': 'DAYS_ON', 'text': '4 days on Zillow'}      None    False                False                 False  ForSale  For Sale (Broker)      None                       False       False     False      False  Listing provided by ABOR  https://photos.zillowstatic.com/fp/98ab7c7b2895c2f5f278917766712625-zillow_web_48_23.jpg                 Coldwell Banker Realty                       True
# 17   2066390614  2066390614          29614702  https://photos.zillowstatic.com/fp/ff3cfcdcd0227aba979b0544d5108542-p_e.jpg      True                          https://www.zillow.com/community/titan-factory-direct-austin/2066390614_zpid/   FOR_SALE  New construction               $    $138,000+            138000    The Casablanca Plan, Titan Factory Direct - Austin  The Casablanca Plan, Titan Factory Direct - Austin        Austin           TX          78741                 False     2    1.0    850    {'latitude': 30.21221, 'longitude': -97.70791}          False                  {'type': 'OPEN_HOUSE', 'text': 'Open: Monday - Saturday...'}      None    False                False                 False  ForSale   New Construction      None                       False        True     False      False                       NaN                                                                                       NaN                                    NaN                       True
# 18    241933065   241933065              None  https://photos.zillowstatic.com/fp/9333f054ebe4ce85dd24a9f5358072ac-p_e.jpg      True              https://www.zillow.com/homedetails/7116-Sienna-Rouge-Path-Austin-TX-78744/241933065_zpid/   FOR_SALE            Active               $     $575,000            575000              7116 Sienna Rouge Path, Austin, TX 78744                              7116 Sienna Rouge Path        Austin           TX          78744                 False     3    3.0   2035    {'latitude': 30.164726, 'longitude': -97.7244}          False                       {'type': 'PRICE_REDUCTION', 'text': '$20,000 (Jun 24)'}      None    False                False                 False  ForSale  For Sale (Broker)    603300                       False       False     False      False  Listing provided by ABOR  https://photos.zillowstatic.com/fp/98ab7c7b2895c2f5f278917766712625-zillow_web_48_23.jpg                          Realty Austin                       True
# 19     29504159    29504159              None  https://photos.zillowstatic.com/fp/40cfcf10910a767bd1296074a439741e-p_e.jpg      True                       https://www.zillow.com/homedetails/2709-Cheney-Cv-Austin-TX-78745/29504159_zpid/   FOR_SALE            Active               $     $450,000            450000                      2709 Cheney Cv, Austin, TX 78745                                      2709 Cheney Cv        Austin           TX          78745                 False     3    2.0   1151   {'latitude': 30.188982, 'longitude': -97.82884}          False                    {'type': 'VIDEO_WALKTHROUGH', 'text': 'Video Walkthrough'}      None    False                False                 False  ForSale  For Sale (Broker)    449900                       False       False      True      False  Listing provided by ABOR  https://photos.zillowstatic.com/fp/98ab7c7b2895c2f5f278917766712625-zillow_web_48_23.jpg                 
days on Zillow'}      None    False                False                 False  ForSale  For Sale (Broker)    307100                       False       False     False      False  Listing provided by ABOR  https://photos.zillowstatic.com/fp/98ab7c7b2895c2f5f278917766712625-zillow_web_48_23.jpg                    Ronny Burns, Broker                       True
# 44    112746974   112746974              None  https://photos.zillowstatic.com/fp/f99ac700165b76cabc7bf5122641c0e1-p_e.jpg      True                 https://www.zillow.com/homedetails/1472-Buffalo-Gap-Rd-Austin-TX-78734/112746974_zpid/   FOR_SALE            Active               $     $695,000            695000                 1472 Buffalo Gap Rd, Austin, TX 78734                                 1472 Buffalo Gap Rd        Austin           TX          78734                 False     4    3.0   2572   {'latitude': 30.38255, 'longitude': -97.956375}          False                       {'type': 'PRICE_REDUCTION', 'text': '$40,000 (Jun 15)'}      None    False                False                 False  ForSale  For Sale (Broker)      None                       False       False     False      False  Listing provided by ABOR  https://photos.zillowstatic.com/fp/98ab7c7b2895c2f5f278917766712625-zillow_web_48_23.jpg                            JPAR Austin                       True
# 45     29369457    29369457              None  https://photos.zillowstatic.com/fp/5acf1b111ffecb5abfd6a04ac10890c7-p_e.jpg      True                https://www.zillow.com/homedetails/11600-Autumn-Ridge-Dr-Austin-TX-78759/29369457_zpid/   FOR_SALE            Active               $     $879,000            879000               11600 Autumn Ridge Dr, Austin, TX 78759                               11600 Autumn Ridge Dr        Austin           TX          78759                 False     4    3.0   2730   {'latitude': 30.422838, 'longitude': -97.76119}          False                               {'type': 'DAYS_ON', 'text': '3 days on Zillow'}      None    False                False                 False  ForSale  For Sale (Broker)      None                       False       False     False      False  Listing provided by ABOR  https://photos.zillowstatic.com/fp/98ab7c7b2895c2f5f278917766712625-zillow_web_48_23.jpg                       Kopa Real Estate                       True
# 46   2086641410  2086641410              None  https://photos.zillowstatic.com/fp/8652227dd221d3dfa7eec8126ca76a60-p_e.jpg      True          https://www.zillow.com/homedetails/8730-N-Mopac-Expy-APT-109-Austin-TX-78759/2086641410_zpid/   FOR_SALE            Active               $     $269,000            269000           8730 N Mopac Expy APT 109, Austin, TX 78759                           8730 N Mopac Expy APT 109        Austin           TX          78759                 False     2    2.0   1080   {'latitude': 30.375666, 'longitude': -97.74061}          False                               {'type': 'DAYS_ON', 'text': '4 days on Zillow'}      None    False                False                 False  ForSale  For Sale (Broker)      None                       False       False     False      False  Listing provided by ABOR  https://photos.zillowstatic.com/fp/98ab7c7b2895c2f5f278917766712625-zillow_web_48_23.jpg                   Bramlett Residential                       True
# ...
# 312              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 313              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 314              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 315              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 316              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 317              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 318              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 319              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 320              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 321              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 322              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 323              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 324              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 325              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 326              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 327              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 328              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 329              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 330              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 331              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 332              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 333              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 334              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 335              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 336              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 337              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 338              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 339              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 340              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 341              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 342              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 343              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 344              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 345              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 346              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 347              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 348              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 349              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 350              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 351              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 352              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 353              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 354              False             None  True    False                   NaN         True      Open House - 1:00 - 5:00 PM  2022-07-02T17:00:00  2022-07-02T13:00:00           NaN
# 355              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 356              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 357              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 358              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 359              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 360              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 361              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 362              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 363              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 364              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 365              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 366              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 367              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 368              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 369              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 370              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 371              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 372              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 373              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 374              False             None  True    False        Waterloo Homes          NaN                              NaN                  NaN                  NaN           NaN
# 375              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 376              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 377              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 378              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 379              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 380              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 381              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 382              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 383              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 384              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 385              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 386              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 387              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 388              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 389              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 390              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 391              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 392              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 393              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 394              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 395              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 396              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 397              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 398              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN
# 399              False             None  True    False                   NaN          NaN                              NaN                  NaN                  NaN           NaN

# %% [markdown]
# # Old

# %%
import os
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
import sys
import numpy as np
import pandas as pd
import regex as re
import requests
import lxml
from lxml.html.soupparser import fromstring
import prettify
import numbers
import htmltext
import json

#set some display settings for notebooks
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', None)

#add headers in case you use chromedriver (captchas are no fun); namely used for chromedriver
req_headers = {
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8',
    'accept-encoding': 'gzip, deflate, br',
    'accept-language': 'en-US,en;q=0.8',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36'
}

#create url variables for each zillow page
with requests.Session() as s:
    city = 'austin/' #*****change this city to what you want!!!!*****
    
    url = 'https://www.zillow.com/homes/for_sale/'+city
    url2 = 'https://www.zillow.com/homes/for_sale/'+city+'/2_p/'
    url3 = 'https://www.zillow.com/homes/for_sale/'+city+'/3_p/'
    url4 = 'https://www.zillow.com/homes/for_sale/'+city+'/4_p/'
    url5 = 'https://www.zillow.com/homes/for_sale/'+city+'/5_p/'
    url6 = 'https://www.zillow.com/homes/for_sale/'+city+'/6_p/'
    url7 = 'https://www.zillow.com/homes/for_sale/'+city+'/7_p/'
    url8 = 'https://www.zillow.com/homes/for_sale/'+city+'/8_p/'
    url9 = 'https://www.zillow.com/homes/for_sale/'+city+'/9_p/'
    url10 = 'https://www.zillow.com/homes/for_sale/'+city+'/10_p/'

    r = s.get(url, headers=req_headers)
    r2 = s.get(url2, headers=req_headers)
    r3 = s.get(url3, headers=req_headers)
    r4 = s.get(url4, headers=req_headers)
    r5 = s.get(url5, headers=req_headers)
    r6 = s.get(url6, headers=req_headers)
    r7 = s.get(url7, headers=req_headers)
    r8 = s.get(url8, headers=req_headers)
    r9 = s.get(url9, headers=req_headers)
    r10 = s.get(url10, headers=req_headers)
    
    url_links = [url, url2, url3, url4, url5, url6, url7, url8, url9, url10]

#add contents of urls to soup variable from each url
soup = BeautifulSoup(r.content, 'html.parser')
soup1 = BeautifulSoup(r2.content, 'html.parser')
soup2 = BeautifulSoup(r3.content, 'html.parser')
soup3 = BeautifulSoup(r4.content, 'html.parser')
soup4 = BeautifulSoup(r5.content, 'html.parser')
soup5 = BeautifulSoup(r6.content, 'html.parser')
soup6 = BeautifulSoup(r7.content, 'html.parser')
soup7 = BeautifulSoup(r8.content, 'html.parser')
soup8 = BeautifulSoup(r9.content, 'html.parser')
soup9 = BeautifulSoup(r10.content, 'html.parser')

# page_links = [soup, soup1, soup2, soup3, soup4, soup5, soup6, soup7, soup8, soup9]

#create the first two dataframes
df = pd.DataFrame()
df1 = pd.DataFrame()

#all for loops are pulling the specified variable using beautiful soup and inserting into said variable
for i in soup:
    address = soup.find_all (class_= 'list-card-addr')
    price = list(soup.find_all (class_='list-card-price'))
    beds = list(soup.find_all("ul", class_="list-card-details"))
    details = soup.find_all ('div', {'class': 'list-card-details'})
    home_type = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link = soup.find_all (class_= 'list-card-link')
    
    #create dataframe columns out of variables
    df['prices'] = price
    df['address'] = address
    df['beds'] = beds

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href == None:
        addresses = None
    else:
        addresses = href.find('address',class_="list-card-addr").get_text()
    urls.append(addresses)
    urls = [x for x in urls if x is not None]

df['links'] = urls
df['links'] = df['links'].astype('str')

#zestimate
data1 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r.text).group(1))
for item in data1['cat1']['searchResults']['listResults']:
    price1=str(item['unformattedPrice'])
    df['zestimate'] = price1

for i in soup1:
    address1 = soup1.find_all (class_= 'list-card-addr')
    price1 = list(soup1.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    details1 = soup1.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup1.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup1.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup1.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup1.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df1['prices'] = price1
    df1['address'] = address1
    df1['beds'] = beds

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup1.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href == None:
        addresses = None
    else:
        addresses = href.find('address',class_="list-card-addr").get_text()
    urls.append(addresses)
    urls = [x for x in urls if x is not None]

#import urls into a links column
df1['links'] = urls
df1['links'] = df1['links'].astype('str')

#zestimate
data2 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r2.text).group(1))
for item in data2['cat1']['searchResults']['listResults']:
    price2=str(item['unformattedPrice'])
    df1['zestimate'] = price2

#append first two dataframes
df = df.append(df1, ignore_index = True) 

#create empty dataframes
df2 = pd.DataFrame()
df3 = pd.DataFrame()
df4 = pd.DataFrame()
df5 = pd.DataFrame()
df6 = pd.DataFrame()
df7 = pd.DataFrame()
df8 = pd.DataFrame()
df9 = pd.DataFrame()

for i in soup2:
    soup = soup2
    address = soup.find_all (class_= 'list-card-addr')
    price = list(soup.find_all (class_='list-card-price'))
    beds = list(soup.find_all("ul", class_="list-card-details"))
    details = soup.find_all ('div', {'class': 'list-card-details'})
    home_type = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link = soup.find_all (class_= 'list-card-link')
    
    #create dataframe columns out of variables
    df2['prices'] = price
    df2['address'] = address
    df2['beds'] = beds

time.sleep(3.2)    

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup2.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href == None:
        addresses = None
    else:
        addresses = href.find('address',class_="list-card-addr").get_text()
    urls.append(addresses)
    urls = [x for x in urls if x is not None]

#import urls into a links column
df2['links'] = urls
df2['links'] = df2['links'].astype('str')

#zestimate
data3 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r3.text).group(1))
for item in data3['cat1']['searchResults']['listResults']:
    price3=str(item['unformattedPrice'])
    df2['zestimate'] = price3

for i in soup3:
    soup = soup3
    address1 = soup.find_all (class_= 'list-card-addr')
    price1 = list(soup.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    details1 = soup.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df3['prices'] = price1
    df3['address'] = address1
    df3['beds'] = beds

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup3.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href == None:
        addresses = None
    else:
        addresses = href.find('address',class_="list-card-addr").get_text()
    urls.append(addresses)
    urls = [x for x in urls if x is not None]

#import urls into a links column
df3['links'] = urls
df3['links'] = df3['links'].astype('str')

#zestimate
data4 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r4.text).group(1))
for item in data4['cat1']['searchResults']['listResults']:
    price4=str(item['unformattedPrice'])
    df3['zestimate'] = price4

for i in soup4:
    soup = soup4
    address1 = soup.find_all (class_= 'list-card-addr')
    price1 = list(soup.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    details1 = soup.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df4['prices'] = price1
    df4['address'] = address1
    df4['beds'] = beds

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup4.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href == None:
        addresses = None
    else:
        addresses = href.find('address',class_="list-card-addr").get_text()
    urls.append(addresses)
    urls = [x for x in urls if x is not None]

#import urls into a links column
df4['links'] = urls
df4['links'] = df4['links'].astype('str')

#zestimate
data5 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r5.text).group(1))
for item in data5['cat1']['searchResults']['listResults']:
    price5=str(item['unformattedPrice'])
    df4['zestimate'] = price5

for i in soup5:
    soup = soup5
    address1 = soup.find_all (class_= 'list-card-addr')
    price1 = list(soup.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    details1 = soup.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df5['prices'] = price1
    df5['address'] = address1
    df5['beds'] = beds

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup5.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href == None:
        addresses = None
    else:
        addresses = href.find('address',class_="list-card-addr").get_text()
    urls.append(addresses)
    urls = [x for x in urls if x is not None]

#import urls into a links column
df5['links'] = urls
df5['links'] = df5['links'].astype('str')

#zestimate
data6 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r6.text).group(1))
for item in data6['cat1']['searchResults']['listResults']:
    price6=str(item['unformattedPrice'])
    df5['zestimate'] = price6
    
for i in soup6:
    soup = soup6
    address1 = soup.find_all (class_= 'list-card-addr')
    price1 = list(soup.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    details1 = soup.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df6['prices'] = price1
    df6['address'] = address1
    df6['beds'] = beds

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup6.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href == None:
        addresses = None
    else:
        addresses = href.find('address',class_="list-card-addr").get_text()
    urls.append(addresses)
    urls = [x for x in urls if x is not None]

time.sleep(3)

#import urls into a links column
df6['links'] = urls
df6['links'] = df6['links'].astype('str')

#zestimate
data7 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r7.text).group(1))
for item in data7['cat1']['searchResults']['listResults']:
    price7=str(item['unformattedPrice'])
    df6['zestimate'] = price7
    
for i in soup7:
    soup = soup7
    address1 = soup.find_all (class_= 'list-card-addr')
    price1 = list(soup.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    details1 = soup.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df7['prices'] = price1
    df7['address'] = address1
    df7['beds'] = beds

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup7.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href == None:
        addresses = None
    else:
        addresses = href.find('address',class_="list-card-addr").get_text()
    urls.append(addresses)
    urls = [x for x in urls if x is not None]

#import urls into a links column
df7['links'] = urls
df7['links'] = df7['links'].astype('str')

#zestimate
data8 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r8.text).group(1))
for item in data8['cat1']['searchResults']['listResults']:
    price8=str(item['unformattedPrice'])
    df7['zestimate'] = price8
    
for i in soup8:
    soup = soup8
    address1 = soup.find_all (class_= 'list-card-addr')
    price1 = list(soup.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    details1 = soup.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df8['prices'] = price1
    df8['address'] = address1
    df8['beds'] = beds

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup8.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href == None:
        addresses = None
    else:
        addresses = href.find('address',class_="list-card-addr").get_text()
    urls.append(addresses)
    urls = [x for x in urls if x is not None]

#import urls into a links column
df8['links'] = urls
df8['links'] = df8['links'].astype('str')

#zestimate
data9 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r9.text).group(1))
for item in data9['cat1']['searchResults']['listResults']:
    price9=str(item['unformattedPrice'])
    df8['zestimate'] = price9

for i in soup9:
    soup = soup9
    address1 = soup.find_all (class_= 'list-card-addr')
    price1 = list(soup.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    details1 = soup.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df9['prices'] = price1
    df9['address'] = address1
    df9['beds'] = beds

#create empty url list
urls = []

#loop through url, pull the href and strip out the address tag
for link in soup9.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href == None:
        addresses = None
    else:
        addresses = href.find('address',class_="list-card-addr").get_text()
    urls.append(addresses)
    urls = [x for x in urls if x is not None]

#import urls into a links column
df9['links'] = urls
df9['links'] = df9['links'].astype('str')

#zestimate
data10 = json.loads(re.search(r'!--(\{"queryState".*?)-->', r10.text).group(1))
for item in data10['cat1']['searchResults']['listResults']:
    price10=str(item['unformattedPrice'])
    df9['zestimate'] = price10

df = df.append(df2, ignore_index = True) 
df = df.append(df3, ignore_index = True) 
df = df.append(df4, ignore_index = True) 
df = df.append(df5, ignore_index = True) 
df = df.append(df6, ignore_index = True) 
df = df.append(df7, ignore_index = True) 
df = df.append(df8, ignore_index = True) 
df = df.append(df9, ignore_index = True)

#convert columns to str
df['prices'] = df['prices'].astype('str')
df['address'] = df['address'].astype('str')
df['beds'] = df['beds'].astype('str')

#remove html tags
df['prices'] = df['prices'].replace('<div class="list-card-price">', ' ', regex=True)
df['address'] = df['address'].replace('<address class="list-card-addr">', ' ', regex=True)
df['prices'] = df['prices'].replace('</div>', ' ', regex=True)
df['address'] = df['address'].replace('</address>', ' ', regex=True)
df['prices'] = df['prices'].str.replace(r'\D', '')

#remove html tags from beds column 
df['beds'] = df['beds'].replace('<ul class="list-card-details"><li class="">', ' ', regex=True)
df['beds'] = df['beds'].replace('<ul class="list-card-details"><li>', ' ', regex=True)
df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->bds</', ' ', regex=True)
df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->bds</abbr></li><li>', ' ', regex=True)
df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->ba</abbr></li><li>', ' ', regex=True)
df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->bd</abbr></li><li>', ' ', regex=True)
df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->sqft</abbr></li></ul>', ' ', regex=True)
df['beds'] = df['beds'].replace(' abbr></li><li class="">', '|', regex=True)
df['beds'] = df['beds'].replace('Studio</li><li>', '0 ', regex=True)
df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->ba</', ' ', regex=True)
df['beds'] = df['beds'].replace(' abbr></li><li class="">', '|', regex=True)
df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->sqft</abbr></li><li class="list-card-statusText">- House for sale</li></ul>', ' ', regex=True)
df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->sqft</abbr></li><li class="list-card-statusText">- Condo for sale</li></ul>', ' ', regex=True)
df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->sqft</abbr></li><li class="list-card-statusText">-<abbr class="list-card-label"> <!-- -->Active</abbr></li></ul>', ' ', regex=True)
df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->bd</abbr></li><li class="">', '|', regex=True)

df.columns = ['prices','address','bed_bath_sqft','links','zestimate']
df['zestimate'] = df['zestimate'].astype(float)

#remove commas from sq_feet and convert to float
df.replace(',','', regex=True, inplace=True)

#drop nulls
df = df[(df['prices'] != '') & (df['prices']!= ' ')]

#convert column to float
df['prices'] = df['prices'].astype('float')
# d['sq_feet'] = df['sq_feet'].astype('float')

#split bed bad sq ft
try:
    x = df[['bed','bath','sq_ft']] = df.bed_bath_sqft.str.split("|",expand=True)
except ValueError:
    pass

#display
print('The dataframe shape is:', df.shape)
# display(df.head())

#create best deal column and sort by best_deal
df ['best_deal'] = df['prices'] - df['zestimate']
df = df.sort_values(by='best_deal')

df
